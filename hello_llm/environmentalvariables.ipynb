# %%
import os
from dotenv import load_dotenv

# %%
#before loading
path=os.getenv('WHYTESTING')
print(path)
# Out:
# None

# %%
load_dotenv()
path=os.getenv('WHYTESTING')
print(path)
# Out:
# this is for fun
