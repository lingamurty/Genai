# %%
from langchain.chat_models import init_chat_model, BaseChatModel
from dotenv import load_dotenv

# %%
model_name = 'google_genai:gemini-3.5-flash-lite'
load_dotenv()
# Out:
# True

# %%
model = init_chat_model(
    model_name
)
model.invoke("what is capital of france")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'El4KXAERTTIP1yi/tm9R3xJGGWUeuPUl1MuSaSAy9E8cDy4P0W/gYXDJDOvgFsN3m2taH2dyvsIy+1PnFs/nJHFWNZhIWGI/UAqSEdJFO8emHh1EZ6kD+v2xQds5ta6P'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a096f3-4990-7ba1-b959-806f8258d89f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 8, 'total_tokens': 14, 'input_token_details': {'cache_read': 0}})

# %%
from langchain.messages import HumanMessage

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages(
    [
        ("human", "What is capital of {country}"),
         ("human", "explain sigficiant of some {topic}")
    ]
)

# %%
model.invoke("What is captial of france?")
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is **Paris**.', 'extras': {'signature': 'El4KXAERTTIPw5ba+bfo6h9UhCieOUAwRQ/x97Hgt7md4lignarbi4qxa+JOlGO6kAZBLkLS2Pclal5qzW7EuairgsRKXyUj2Mo+9gFvzFHL70s19vvVkHrJFjp5ZWsy'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a096f3-537d-7c00-9f86-3820104d8e17-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 8, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})

# %%
chain = prompt_template | model

# %%
type(chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %%
chain.invoke({
    'country': 'India',
    'topic':'pollution'
})
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of India is **New Delhi**. It serves as the seat of the executive, legislative, and judiciary branches of the Government of India, and is the center of the National Capital Territory (NCT).\n\nWhen discussing the **significance of pollution** in New Delhi, it is important to understand that pollution—particularly air pollution—is not just an environmental issue for the city; it is a profound crisis with massive health, economic, and social consequences. \n\nHere is an explanation of the significance of various types of pollution in India\'s capital:\n\n---\n\n### 1. Air Pollution (The Most Critical Crisis)\nNew Delhi is frequently ranked among the most polluted cities in the world, especially during the winter months (October to February). The Air Quality Index (AQI) often reaches "Severe" or "Hazardous" levels, sometimes exceeding 500 (where anything above 100 is considered unhealthy).\n\n**Significance and Impacts:**\n*   **Public Health Emergency:** The air is laden with high levels of $\\text{PM}_{2.5}$ and $\\text{PM}_{10}$ (tiny particulate matter that penetrates deep into the lungs and bloodstream). This leads to a massive spike in respiratory diseases (asthma, bronchitis), cardiovascular problems, and lung cancer. Doctors have frequently described living in Delhi during winter as equivalent to smoking 20–30 cigarettes a day. It disproportionately affects children, the elderly, and outdoor workers.\n*   **Economic Loss:** Severe air pollution impacts productivity. Schools are frequently forced to close, shifting to online classes. Businesses suffer due to employee illness, and tourism takes a hit as international advisories warn travelers about Delhi’s toxic air.\n*   **Seasonal Visibility and Safety:** Thick smog drastically reduces visibility, leading to major traffic accidents on highways and the disruption of flights and train schedules at Indira Gandhi International Airport.\n\n**Major Causes:** \nThe significance of Delhi\'s air pollution lies in its complex geography and multiple sources: stubble burning in neighboring states (Punjab and Haryana), vehicular emissions, industrial pollution, construction dust, and the burning of waste, compounded by weather patterns (low wind speeds and drop in temperature that trap pollutants).\n\n---\n\n### 2. Water Pollution (The Yamuna River)\nThe Yamuna River, which flows through Delhi, is considered ecologically dead along the stretch that passes through the city. \n\n**Significance and Impacts:**\n*   **Loss of Aquatic Life:** Despite accounting for only 2% of the river\'s total length, the Delhi stretch contributes over 70% of the pollution in the Yamuna due to untreated sewage and industrial effluents. Fish and other aquatic life cannot survive in most parts of the river within the city.\n*   **Public Health and Sanitation:** Many low-income communities rely on groundwater, which is often contaminated due to improper waste disposal and sewage leakage near the riverbed, leading to waterborne diseases like cholera, typhoid, and dysentery.\n*   **Cultural and Religious Impact:** The Yamuna is considered sacred in Hinduism. The heavy pollution—often visible as thick, toxic foam floating on the water—prevents devotees from performing traditional rituals safely.\n\n---\n\n### 3. Solid Waste and Landfill Pollution\nDelhi generates massive amounts of municipal solid waste daily. Much of this ends up in massive open-air landfills, such as the Ghazipur, Bhalswa, and Okhla landfills.\n\n**Significance and Impacts:**\n*   **Environmental Hazards:** These towering garbage mountains frequently catch fire due to methane gas generation, releasing toxic fumes into the atmosphere and worsening the air quality.\n*   **Leachate Contamination:** Rainwater washes toxic liquids (leachate) from these landfills into the soil, polluting the groundwater table used by nearby settlements.\n*   **Health and Quality of Life:** Millions of people l ...
