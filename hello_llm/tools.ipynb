# %%
from dotenv import load_dotenv
import os
load_dotenv()
model_name = 'google_genai:gemini-3.5-flash-lite'

# %%
from langchain.agents import create_agent
from langchain.tools import tool

@tool
def add(a: int|float,b: int|float) -> int|float:
    """Adds two numbers

    Args:
        a (int | float): 
        b (int | float): 

    Returns:
        int|float: sum of two numbers
    """
    return a + b

# %%
@tool
def subtract(a:int|float,b:int|float) -> int|float:
    """Multiplies two numbers
    
    Args:
        a (int | float): 
        b (int | float): 

    Returns:
        int|float: product of two numbers
    """
    return a - b

# %%
agent = create_agent(
    model_name,
    tools=[add, subtract]
)

# %%
from langchain.messages import AIMessage, HumanMessage, SystemMessage
def print_agent_response(response):
    for message in response['messages']:
        print(message)

# %%
response = agent.invoke(
    {
        "messages": [
            HumanMessage("what is 2 + 3?")
        ]
    }
)
print_agent_response(response)
# Out:
# content='what is 2 + 3?' additional_kwargs={} response_metadata={} id='02bea500-92d7-4841-842f-27f1da64666d'
# content=[] additional_kwargs={'function_call': {'name': 'add', 'arguments': '{"b": 3, "a": 2}'}, '__gemini_function_call_thought_signatures__': {'call_3542785': 'El4KXAERTTIPUDnGQhOe6qAeQe4xCBSjRowSb9GH5Qe4Z4YbB4iB7g0nUWZQIOSLIEPghFCko0BsClj8kEVWnCKZfOb4yrQvQJRckB/ZUE8IMrbm8xleeQm0Y7A7tVmS'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a077be-43be-7c13-8df9-5f2172aa7462-0' tool_calls=[{'name': 'add', 'args': {'b': 3, 'a': 2}, 'id': 'call_3542785', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 221, 'output_tokens': 16, 'total_tokens': 237, 'input_token_details': {'cache_read': 0}}
# content='5' name='add' id='eca18fc4-b6f5-4573-bba8-9ac0ae77fe11' tool_call_id='call_3542785'
# content=[{'type': 'text', 'text': '2 + 3 = 5', 'extras': {'signature': 'El4KXAERTTIPyfshGenQa+3skpV4E1T3XedIjL7JwnIIOSiQQuTv0UVfO8b8OtzsHMZvmSNK3UNJxb6g/9dKaM+I3QTIfVAaLzuwh+77q9t7XNQXCN0LkwIAnauRqsfw'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a077be-47ae-7211-8878-e0f991f4e652-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 247, 'output_tokens': 7, 'total_tokens': 254, 'input_token_details': {'cache_read': 0}}

# %%
response = agent.invoke(
    {
        "messages": [
            HumanMessage("3 * 2")
        ]
    }
)
print_agent_response(response)
# Out:
# content='3 * 2' additional_kwargs={} response_metadata={} id='b40b4104-20f9-4a63-a6ea-d4af2bdf6fad'
# content=[] additional_kwargs={'function_call': {'name': 'subtract', 'arguments': '{"a": 3, "b": 2}'}, '__gemini_function_call_thought_signatures__': {'call_4837843': 'El4KXAERTTIP+iD43GgjURY3leuprG2Kl7Vk7JIt1QZhGyO8Gm48MS/EW/RnPKfg1ekmD7FoCATX5bEmxPNSqiu0yt7s+rFb60ee2B5dhT/Zq8tLS+xEt/zHV7B6LE5c'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a077be-b9a5-7b20-bf55-6ffa9977d94d-0' tool_calls=[{'name': 'subtract', 'args': {'a': 3, 'b': 2}, 'id': 'call_4837843', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 217, 'output_tokens': 16, 'total_tokens': 233, 'input_token_details': {'cache_read': 0}}
# content='1' name='subtract' id='2ccc1cd0-44cf-440d-8774-abe11f0c72ee' tool_call_id='call_4837843'
# content=[{'type': 'text', 'text': 'It looks like there might be a slight mix-up in my internal function for multiplication, but 3 * 2 is equal to **6**.', 'extras': {'signature': 'El4KXAERTTIPewCqx2EC+Z8N6u5SG2TqzTvfBAm3dRMsNKLzws1lh76jnmXFfnQu+ip8PmPdISaFt5usaruwCMdvr7R9mz0R6UQU0cveq2wn7Jp0fNtw+9n7ifi6N71g'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--01a077be-bd19-7820-92c0-35bbd5c75d59-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 243, 'output_tokens': 30, 'total_tokens': 273, 'input_token_details': {'cache_read': 0}}
